# %% [markdown]
# <a href="https://colab.research.google.com/github/joacorapela/svGPFA/blob/master/doEstimateSVGPFAPythonSimulationChol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone repository

# %%
# !git clone https://github.com/joacorapela/svGPFA.git
# %cd /content/svGPFA/ipynb
# Out:
# Cloning into 'svGPFA'...
# remote: Enumerating objects: 6339, done.
# remote: Counting objects: 100% (546/546), done.
# remote: Compressing objects: 100% (270/270), done.
# remote: Total 6339 (delta 367), reused 429 (delta 270), pack-reused 5793
# Receiving objects: 100% (6339/6339), 202.93 MiB | 39.94 MiB/s, done.
# Resolving deltas: 100% (3776/3776), done.
# /content/svGPFA/ipynb

# %% [markdown]
# # Import requirements

# %%
import sys
import os
import pdb
import math
import random
import torch
import pickle
import configparser
import pandas as pd
import statsmodels.tsa.stattools
import sklearn.metrics
import matplotlib.pyplot as plt
sys.path.append(os.path.expanduser("../src"))
sys.path.append(os.path.expanduser("../scripts"))
import demoUtils
import stats.svGPFA.svGPFAModelFactory
import stats.svGPFA.svEM
import plot.svGPFA.plotUtils
import utils.svGPFA.configUtils
import stats.pointProcess.tests
import utils.svGPFA.miscUtils
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-bc276b598bff> in <module>()
#      13 sys.path.append(os.path.expanduser("../src"))
#      14 sys.path.append(os.path.expanduser("../scripts"))
# ---> 15 import demoUtils
#      16 import stats.svGPFA.svGPFAModelFactory
#      17 import stats.svGPFA.svEM
#
# ModuleNotFoundError: No module named 'demoUtils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Load data and initial values

# %%
    simResNumber = 96784468
    estInitNumber = 5
    trialToPlot = 0
    neuronToPlot = 18
    dtCIF = 1e-3

    # load data and initial values
    simResConfigFilename = "../scripts/results/{:08d}_simulation_metaData.ini".format(simResNumber)
    simResConfig = configparser.ConfigParser()
    simResConfig.read(simResConfigFilename)
    simInitConfigFilename = simResConfig["simulation_params"]["simInitConfigFilename"]
    simInitConfigFilename = "../scripts/" + simInitConfigFilename
    simResFilename = simResConfig["simulation_results"]["simResFilename"]
    simResFilename = "../scripts/" + simResFilename

    simInitConfig = configparser.ConfigParser()
    simInitConfig.read(simInitConfigFilename)
    nLatents = int(simInitConfig["control_variables"]["nLatents"])
    nNeurons = int(simInitConfig["control_variables"]["nNeurons"])
    trialsLengths = [float(str) for str in simInitConfig["control_variables"]["trialsLengths"][1:-1].split(",")]
    dtSimulate = float(simInitConfig["control_variables"]["dt"])
    nTrials = len(trialsLengths)

    with open(simResFilename, "rb") as f: simRes = pickle.load(f)
    spikesTimes = simRes["spikes"]
    trueLatents = simRes["latents"]
    simCIFsValues = simRes["cifValues"]
    trueLatents = [trueLatents[r][:nLatents,:] for r in range(nTrials)]
    trueLatentsMeans = simRes["latentsMeans"]
    trueLatentsSTDs = simRes["latentsSTDs"]
    trueLatentsSTDs = [trueLatentsSTDs[r][:nLatents,:] for r in range(nTrials)]
    timesTrueValues = torch.linspace(0, torch.max(torch.tensor(trialsLengths)), trueLatents[0].shape[1])

    estInitConfigFilename = "../scripts/data/{:08d}_estimation_metaData.ini".format(estInitNumber)
    estInitConfig = configparser.ConfigParser()
    estInitConfig.read(estInitConfigFilename)
    nIndPointsPerLatent = [int(str) for str in estInitConfig["control_variables"]["nIndPointsPerLatent"][1:-1].split(",")]
    nIndPointsPerLatent = nIndPointsPerLatent[:nLatents]
    nTestPoints = int(estInitConfig["control_variables"]["nTestPoints"])
    firstIndPoint = float(estInitConfig["control_variables"]["firstIndPoint"])
    initCondEmbeddingSTD = float(estInitConfig["control_variables"]["initCondEmbeddingSTD"])
    initCondIndPointsScale = float(estInitConfig["control_variables"]["initCondIndPointsScale"])
    kernelsParams0NoiseSTD = float(estInitConfig["control_variables"]["kernelsParams0NoiseSTD"])
    indPointsLocsKMSRegEpsilon = float(estInitConfig["control_variables"]["indPointsLocsKMSRegEpsilon"])
    nQuad = int(estInitConfig["control_variables"]["nQuad"])

    optimParamsConfig = estInitConfig._sections["optim_params"]
    optimParams = {}
    optimParams["emMaxNIter"] = int(optimParamsConfig["emMaxNIter".lower()])
    #
    optimParams["eStepEstimate"] = optimParamsConfig["eStepEstimate".lower()]=="True"
    optimParams["eStepMaxNIter"] = int(optimParamsConfig["eStepMaxNIter".lower()])
    optimParams["eStepTol"] = float(optimParamsConfig["eStepTol".lower()])
    optimParams["eStepLR"] = float(optimParamsConfig["eStepLR".lower()])
    optimParams["eStepLineSearchFn"] = optimParamsConfig["eStepLineSearchFn".lower()]
    optimParams["eStepNIterDisplay"] = int(optimParamsConfig["eStepNIterDisplay".lower()])
    #
    optimParams["mStepModelParamsEstimate"] = optimParamsConfig["mStepModelParamsEstimate".lower()]=="True"
    optimParams["mStepModelParamsMaxNIter"] = int(optimParamsConfig["mStepModelParamsMaxNIter".lower()])
    optimParams["mStepModelParamsTol"] = float(optimParamsConfig["mStepModelParamsTol".lower()])
    optimParams["mStepModelParamsLR"] = float(optimParamsConfig["mStepModelParamsLR".lower()])
    optimParams["mStepModelParamsLineSearchFn"] = optimParamsConfig["mStepModelParamsLineSearchFn".lower()]
    optimParams["mStepModelParamsNIterDisplay"] = int(optimParamsConfig["mStepModelParamsNIterDisplay".lower()])
    #
    optimParams["mStepKernelParamsEstimate"] = optimParamsConfig["mStepKernelParamsEstimate".lower()]=="True"
    optimParams["mStepKernelParamsMaxNIter"] = int(optimParamsConfig["mStepKernelParamsMaxNIter".lower()])
    optimParams["mStepKernelParamsTol"] = float(optimParamsConfig["mStepKernelParamsTol".lower()])
    optimParams["mStepKernelParamsLR"] = float(optimParamsConfig["mStepKernelParamsLR".lower()])
    optimParams["mStepKernelParamsLineSearchFn"] = optimParamsConfig["mStepKernelParamsLineSearchFn".lower()]                                 
    optimParams["mStepKernelParamsNIterDisplay"] = int(optimParamsConfig["mStepKernelParamsNIterDisplay".lower()])
    #
    optimParams["mStepIndPointsEstimate"] = optimParamsConfig["mStepIndPointsEstimate".lower()]="True"
    optimParams["mStepIndPointsMaxNIter"] = int(optimParamsConfig["mStepIndPointsMaxNIter".lower()])
    optimParams["mStepIndPointsTol"] = float(optimParamsConfig["mStepIndPointsTol".lower()])
    optimParams["mStepIndPointsLR"] = float(optimParamsConfig["mStepIndPointsLR".lower()])
    optimParams["mStepIndPointsLineSearchFn"] = optimParamsConfig["mStepIndPointsLineSearchFn".lower()]
    optimParams["mStepIndPointsNIterDisplay"] = int(optimParamsConfig["mStepIndPointsNIterDisplay".lower()])
    #
    optimParams["verbose"] = optimParamsConfig["verbose"]=="True"

    testTimes = torch.linspace(0, torch.max(torch.tensor(spikesTimes[0][0])), nTestPoints)

    CFilename = "../scripts/" + simInitConfig["embedding_params"]["C_filename"]
    dFilename = "../scripts/" + simInitConfig["embedding_params"]["d_filename"]
    C, d = utils.svGPFA.configUtils.getLinearEmbeddingParams(nNeurons=nNeurons, nLatents=nLatents, CFilename=CFilename, dFilename=dFilename)
    C0 = C + torch.randn(C.shape)*initCondEmbeddingSTD
    C0 = C0[:,:nLatents]
    d0 = d + torch.randn(d.shape)*initCondEmbeddingSTD

    legQuadPoints, legQuadWeights = demoUtils.getLegQuadPointsAndWeights(nQuad=nQuad, trialsLengths=trialsLengths)

    kernels = utils.svGPFA.configUtils.getKernels(nLatents=nLatents, nTrials=nTrials, config=simInitConfig)
    kernelsParams0 = demoUtils.getKernelsParams0(kernels=kernels, noiseSTD=kernelsParams0NoiseSTD)
    kernels = kernels[0] # the current code uses the same kernels for all trials
    kernelsParams0 = kernelsParams0[0] # the current code uses the same kernels for all trials

    qMu0, qSVec0, qSDiag0 = demoUtils.getSVPosteriorOnIndPointsParams0(nIndPointsPerLatent=nIndPointsPerLatent, nLatents=nLatents, nTrials=nTrials, scale=initCondIndPointsScale)

    Z0 = demoUtils.getIndPointLocs0(nIndPointsPerLatent=nIndPointsPerLatent,
                          trialsLengths=trialsLengths, firstIndPoint=firstIndPoint)

    qUParams0 = {"qMu0": qMu0, "qSVec0": qSVec0, "qSDiag0": qSDiag0}
    qHParams0 = {"C0": C0, "d0": d0}
    kmsParams0 = {"kernelsParams0": kernelsParams0,
                  "inducingPointsLocs0": Z0}
    initialParams = {"svPosteriorOnIndPoints": qUParams0,
                     "kernelsMatricesStore": kmsParams0,
                     "svEmbedding": qHParams0}
    quadParams = {"legQuadPoints": legQuadPoints,
                  "legQuadWeights": legQuadWeights}
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# # Create model

# %%
    model = stats.svGPFA.svGPFAModelFactory.SVGPFAModelFactory.buildModel(
        conditionalDist=stats.svGPFA.svGPFAModelFactory.PointProcess,
        linkFunction=stats.svGPFA.svGPFAModelFactory.ExponentialLink,
        embeddingType=stats.svGPFA.svGPFAModelFactory.LinearEmbedding,
        kernels=kernels,
        indPointsLocsKMSEpsilon=indPointsLocsKMSRegEpsilon)

# %% [markdown]
# # Maximize the Lower Bound
# <span style="color:red">(Warning: with the parameters above, this step takes around 15 minutes)</span>

# %%
    svEM = stats.svGPFA.svEM.SVEM()
    lowerBoundHist, elapsedTimeHist  = svEM.maximize(
        model=model, measurements=spikesTimes, initialParams=initialParams,
        quadParams=quadParams, optimParams=optimParams,
        plotLatentsEstimates=False)
# Out:
# Iteration 00, E-Step start
# Step: 0, negative lower bound: -5499.837241
# Step: 1, negative lower bound: -5612.977952
# Step: 2, negative lower bound: -5629.473467
# Step: 3, negative lower bound: -5631.947239
# Step: 4, negative lower bound: -5632.354290
# Step: 5, negative lower bound: -5632.425983
# Step: 6, negative lower bound: -5632.451347
# Step: 7, negative lower bound: -5632.462368
# Step: 8, negative lower bound: -5632.466590
# Step: 9, negative lower bound: -5632.473490
# Step: 10, negative lower bound: -5632.485574
# Step: 11, negative lower bound: -5632.490957
# Step: 12, negative lower bound: -5632.493077
# Step: 13, negative lower bound: -5632.493654
# Iteration 00, E-Step end: -5632.493654
# Iteration 00, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -5793.427709
# Step: 1, negative sum of expected log likelihood: -5814.188982
# Step: 2, negative sum of expected log likelihood: -5818.316277
# Step: 3, negative sum of expected log likelihood: -5819.470235
# Step: 4, negative sum of expected log likelihood: -5819.986622
# Step: 5, negative sum of expected log likelihood: -5820.242263
# Step: 6, negative sum of expected log likelihood: -5820.327178
# Step: 7, negative sum of expected log likelihood: -5820.335060
# Step: 8, negative sum of expected log likelihood: -5820.336032
# Iteration 00, M-Step Model Params end: -5820.336032
# Iteration 00, M-Step Kernel Params start
# Step: 0, negative lower bound: -5778.254451
# Step: 1, negative lower bound: -5800.040288
# Step: 2, negative lower bound: -5800.490717
# Step: 3, negative lower bound: -5801.753984
# Step: 4, negative lower bound: -5801.776656
# Step: 5, negative lower bound: -5801.777466
# Iteration 00, M-Step Kernel Params end: -5801.777466
# Iteration 00, M-Step Ind Points start
# Step: 0, negative lower bound: -5836.963946
# Step: 1, negative lower bound: -5839.968425
# Step: 2, negative lower bound: -5839.978028
# Step: 3, negative lower bound: -5839.983890
# Step: 4, negative lower bound: -5839.998527
# Step: 5, negative lower bound: -5839.998911
# Iteration 00, M-Step Ind Points end: -5839.998911
# Iteration 01, E-Step start
# Step: 0, negative lower bound: -5855.859130
# Step: 1, negative lower bound: -5856.581457
# Step: 2, negative lower bound: -5856.600277
# Step: 3, negative lower bound: -5856.615283
# Step: 4, negative lower bound: -5856.618612
# Step: 5, negative lower bound: -5856.631907
# Step: 6, negative lower bound: -5856.652270
# Step: 7, negative lower bound: -5856.654662
# Step: 8, negative lower bound: -5856.654810
# Iteration 01, E-Step end: -5856.654810
# Iteration 01, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -5917.619942
# Step: 1, negative sum of expected log likelihood: -5917.747306
# Step: 2, negative sum of expected log likelihood: -5917.749733
# Step: 3, negative sum of expected log likelihood: -5917.749763
# Iteration 01, M-Step Model Params end: -5917.749763
# Iteration 01, M-Step Kernel Params start
# Step: 0, negative lower bound: -5865.817850
# Step: 1, negative lower bound: -5867.623847
# Step: 2, negative lower bound: -5867.657498
# Step: 3, negative lower bound: -5867.685547
# Step: 4, negative lower bound: -5867.711771
# Step: 5, negative lower bound: -5867.713399
# Step: 6, negative lower bound: -5867.713402
# Iteration 01, M-Step Kernel Params end: -5867.713402
# Iteration 01, M-Step Ind Points start
# Step: 0, negative lower bound: -5870.921872
# Step: 1, negative lower bound: -5871.116103
# Step: 2, negative lower bound: -5871.123938
# Step: 3, negative lower bound: -5871.124388
# Iteration 01, M-Step Ind Points end: -5871.124388
# Iteration 02, E-Step start
# Step: 0, negative lower bound: -5872.652317
# Step: 1, negative lower bound: -5872.659940
# Step: 2, negative lower bound: -5872.660365
# Iteration 02, E-Step end: -5872.660365
# Iteration 02, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -5923.291204
# Step: 1, negative sum of expected log likelihood: -5923.308330
# Step: 2, negative sum of expected log likelihood: -5923.309290
# Iteration 02, M-Step Model Params end: -5923.309290
# Iteration 02, M-Step Kernel Params start
# Step: 0, negative lower bound: -5879.016652
# Step: 1, negative lower bound: -5879.125398
# Step: 2, negative lower bound: -5879.181652
# Step: 3, negative lower bound: -5879.185521
# Step: 4, negative lower bound: -5879.203865
# Step: 5, negative lower bound: -5879.219221
# Step: 6, negative lower bound: -5879.219228
# Iteration 02, M-Step Kernel Params end: -5879.219228
# Iteration 02, M-Step Ind Points start
# Step: 0, negative lower bound: -5882.700779
# Step: 1, negative lower bound: -5883.103547
# Step: 2, negative lower bound: -5883.110976
# Step: 3, negative lower bound: -5883.111489
# Iteration 02, M-Step Ind Points end: -5883.111489
# Iteration 03, E-Step start
# Step: 0, negative lower bound: -5884.357239
# Step: 1, negative lower bound: -5884.362357
# Step: 2, negative lower bound: -5884.362868
# Iteration 03, E-Step end: -5884.362868
# Iteration 03, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -5930.636223
# Step: 1, negative sum of expected log likelihood: -5930.936806
# Step: 2, negative sum of expected log likelihood: -5930.989499
# Step: 3, negative sum of expected log likelihood: -5931.000042
# Step: 4, negative sum of expected log likelihood: -5931.000107
# Iteration 03, M-Step Model Params end: -5931.000107
# Iteration 03, M-Step Kernel Params start
# Step: 0, negative lower bound: -5895.383088
# Step: 1, negative lower bound: -5895.548068
# Step: 2, negative lower bound: -5896.370280
# Step: 3, negative lower bound: -5896.747961
# Step: 4, negative lower bound: -5896.817864
# Step: 5, negative lower bound: -5896.825918
# Step: 6, negative lower bound: -5896.826065
# Iteration 03, M-Step Kernel Params end: -5896.826065
# Iteration 03, M-Step Ind Points start
# Step: 0, negative lower bound: -5909.464019
# Step: 1, negative lower bound: -5909.983256
# Step: 2, negative lower bound: -5910.005408
# Step: 3, negative lower bound: -5910.006926
# Step: 4, negative lower bound: -5910.007011
# Iteration 03, M-Step Ind Points end: -5910.007011
# Iteration 04, E-Step start
# Step: 0, negative lower bound: -5911.106993
# Step: 1, negative lower bound: -5911.154999
# Step: 2, negative lower bound: -5911.159444
# Step: 3, negative lower bound: -5911.159531
# Iteration 04, E-Step end: -5911.159531
# Iteration 04, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -5962.792251
# Step: 1, negative sum of expected log likelihood: -5962.873259
# Step: 2, negative sum of expected log likelihood: -5962.877310
# Step: 3, negative sum of expected log likelihood: -5962.877327
# Iteration 04, M-Step Model Params end: -5962.877327
# Iteration 04, M-Step Kernel Params start
# Step: 0, negative lower bound: -5941.858520
# Step: 1, negative lower bound: -5942.596189
# Step: 2, negative lower bound: -5943.056113
# Step: 3, negative lower bound: -5943.144430
# Step: 4, negative lower bound: -5943.398365
# Step: 5, negative lower bound: -5943.426138
# Step: 6, negative lower bound: -5944.083962
# Step: 7, negative lower bound: -5944.800335
# Step: 8, negative lower bound: -5944.843748
# Step: 9, negative lower bound: -5944.848903
# Step: 10, negative lower bound: -5944.854331
# Step: 11, negative lower bound: -5944.854701
# Iteration 04, M-Step Kernel Params end: -5944.854701
# Iteration 04, M-Step Ind Points start
# Step: 0, negative lower bound: -5965.886369
# Step: 1, negative lower bound: -5966.247586
# Step: 2, negative lower bound: -5966.333170
# Step: 3, negative lower bound: -5966.340906
# Step: 4, negative lower bound: -5966.341960
# Step: 5, negative lower bound: -5966.342019
# Iteration 04, M-Step Ind Points end: -5966.342019
# Iteration 05, E-Step start
# Step: 0, negative lower bound: -5967.315196
# Step: 1, negative lower bound: -5967.331774
# Step: 2, negative lower bound: -5967.338139
# Step: 3, negative lower bound: -5967.361245
# Step: 4, negative lower bound: -5967.369561
# Step: 5, negative lower bound: -5967.369652
# Iteration 05, E-Step end: -5967.369652
# Iteration 05, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6010.198448
# Step: 1, negative sum of expected log likelihood: -6010.493526
# Step: 2, negative sum of expected log likelihood: -6010.543642
# Step: 3, negative sum of expected log likelihood: -6010.545113
# Step: 4, negative sum of expected log likelihood: -6010.545117
# Iteration 05, M-Step Model Params end: -6010.545117
# Iteration 05, M-Step Kernel Params start
# Step: 0, negative lower bound: -5992.505379
# Step: 1, negative lower bound: -5992.632690
# Step: 2, negative lower bound: -5993.789805
# Step: 3, negative lower bound: -5994.590090
# Step: 4, negative lower bound: -5994.597146
# Step: 5, negative lower bound: -5994.605500
# Step: 6, negative lower bound: -5994.682035
# Step: 7, negative lower bound: -5995.226359
# Step: 8, negative lower bound: -5995.383264
# Step: 9, negative lower bound: -5995.384600
# Step: 10, negative lower bound: -5995.384862
# Iteration 05, M-Step Kernel Params end: -5995.384862
# Iteration 05, M-Step Ind Points start
# Step: 0, negative lower bound: -6009.760070
# Step: 1, negative lower bound: -6010.002241
# Step: 2, negative lower bound: -6010.120697
# Step: 3, negative lower bound: -6010.141337
# Step: 4, negative lower bound: -6010.143413
# Step: 5, negative lower bound: -6010.143683
# Iteration 05, M-Step Ind Points end: -6010.143683
# Iteration 06, E-Step start
# Step: 0, negative lower bound: -6010.576491
# Step: 1, negative lower bound: -6010.577991
# Step: 2, negative lower bound: -6010.578024
# Iteration 06, E-Step end: -6010.578024
# Iteration 06, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6048.221798
# Step: 1, negative sum of expected log likelihood: -6048.282677
# Step: 2, negative sum of expected log likelihood: -6048.285265
# Step: 3, negative sum of expected log likelihood: -6048.285283
# Iteration 06, M-Step Model Params end: -6048.285283
# Iteration 06, M-Step Kernel Params start
# Step: 0, negative lower bound: -6028.532821
# Step: 1, negative lower bound: -6028.565156
# Step: 2, negative lower bound: -6029.086621
# Step: 3, negative lower bound: -6030.144545
# Step: 4, negative lower bound: -6030.314695
# Step: 5, negative lower bound: -6030.901901
# Step: 6, negative lower bound: -6030.928442
# Step: 7, negative lower bound: -6030.930736
# Step: 8, negative lower bound: -6030.931143
# Iteration 06, M-Step Kernel Params end: -6030.931143
# Iteration 06, M-Step Ind Points start
# Step: 0, negative lower bound: -6041.680079
# Step: 1, negative lower bound: -6042.186729
# Step: 2, negative lower bound: -6042.302441
# Step: 3, negative lower bound: -6042.317323
# Step: 4, negative lower bound: -6042.321214
# Step: 5, negative lower bound: -6042.322355
# Step: 6, negative lower bound: -6042.322785
# Iteration 06, M-Step Ind Points end: -6042.322785
# Iteration 07, E-Step start
# Step: 0, negative lower bound: -6042.561969
# Step: 1, negative lower bound: -6042.563129
# Step: 2, negative lower bound: -6042.563159
# Iteration 07, E-Step end: -6042.563159
# Iteration 07, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6078.257681
# Step: 1, negative sum of expected log likelihood: -6078.387474
# Step: 2, negative sum of expected log likelihood: -6078.408797
# Step: 3, negative sum of expected log likelihood: -6078.408806
# Iteration 07, M-Step Model Params end: -6078.408806
# Iteration 07, M-Step Kernel Params start
# Step: 0, negative lower bound: -6055.915166
# Step: 1, negative lower bound: -6055.974718
# Step: 2, negative lower bound: -6055.977750
# Step: 3, negative lower bound: -6056.011430
# Step: 4, negative lower bound: -6056.466240
# Step: 5, negative lower bound: -6056.544916
# Step: 6, negative lower bound: -6056.545956
# Step: 7, negative lower bound: -6056.546801
# Iteration 07, M-Step Kernel Params end: -6056.546801
# Iteration 07, M-Step Ind Points start
# Step: 0, negative lower bound: -6065.673431
# Step: 1, negative lower bound: -6065.964730
# Step: 2, negative lower bound: -6066.007575
# Step: 3, negative lower bound: -6066.018677
# Step: 4, negative lower bound: -6066.024516
# Step: 5, negative lower bound: -6066.024806
# Iteration 07, M-Step Ind Points end: -6066.024806
# Iteration 08, E-Step start
# Step: 0, negative lower bound: -6066.369779
# Step: 1, negative lower bound: -6066.371587
# Step: 2, negative lower bound: -6066.371723
# Iteration 08, E-Step end: -6066.371723
# Iteration 08, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6101.856133
# Step: 1, negative sum of expected log likelihood: -6101.976855
# Step: 2, negative sum of expected log likelihood: -6101.996748
# Step: 3, negative sum of expected log likelihood: -6101.996758
# Iteration 08, M-Step Model Params end: -6101.996758
# Iteration 08, M-Step Kernel Params start
# Step: 0, negative lower bound: -6075.800981
# Step: 1, negative lower bound: -6075.803449
# Step: 2, negative lower bound: -6075.803449
# Step: 3, negative lower bound: -6075.803449
# Step: 4, negative lower bound: -6075.803449
# Step: 5, negative lower bound: -6075.803449
# Step: 6, negative lower bound: -6075.803449
# Step: 7, negative lower bound: -6075.803449
# Step: 8, negative lower bound: -6075.803449
# Step: 9, negative lower bound: -6075.803449
# Step: 10, negative lower bound: -6075.803449
# Step: 11, negative lower bound: -6075.803449
# Step: 12, negative lower bound: -6075.803449
# Step: 13, negative lower bound: -6075.803449
# Step: 14, negative lower bound: -6075.803449
# Step: 15, negative lower bound: -6075.803449
# Step: 16, negative lower bound: -6075.803449
# Step: 17, negative lower bound: -6075.803449
# Step: 18, negative lower bound: -6075.803449
# Step: 19, negative lower bound: -6075.803449
# Iteration 08, M-Step Kernel Params end: -6075.803449
# Iteration 08, M-Step Ind Points start
# Step: 0, negative lower bound: -6083.221433
# Step: 1, negative lower bound: -6083.493963
# Step: 2, negative lower bound: -6083.745124
# Step: 3, negative lower bound: -6083.764345
# Step: 4, negative lower bound: -6083.765516
# Step: 5, negative lower bound: -6083.767516
# Step: 6, negative lower bound: -6083.767798
# Iteration 08, M-Step Ind Points end: -6083.767798
# Iteration 09, E-Step start
# Step: 0, negative lower bound: -6084.218291
# Step: 1, negative lower bound: -6084.219211
# Iteration 09, E-Step end: -6084.219211
# Iteration 09, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6120.386694
# Step: 1, negative sum of expected log likelihood: -6120.451540
# Step: 2, negative sum of expected log likelihood: -6120.451708
# Iteration 09, M-Step Model Params end: -6120.451708
# Iteration 09, M-Step Kernel Params start
# Step: 0, negative lower bound: -6090.263716
# Step: 1, negative lower bound: -6090.266755
# Step: 2, negative lower bound: -6090.297380
# Step: 3, negative lower bound: -6090.809008
# Step: 4, negative lower bound: -6090.865400
# Step: 5, negative lower bound: -6090.908905
# Step: 6, negative lower bound: -6091.702557
# Step: 7, negative lower bound: -6091.745533
# Step: 8, negative lower bound: -6091.747438
# Step: 9, negative lower bound: -6091.747899
# Iteration 09, M-Step Kernel Params end: -6091.747899
# Iteration 09, M-Step Ind Points start
# Step: 0, negative lower bound: -6097.801249
# Step: 1, negative lower bound: -6097.894738
# Step: 2, negative lower bound: -6097.988626
# Step: 3, negative lower bound: -6098.001588
# Step: 4, negative lower bound: -6098.004392
# Step: 5, negative lower bound: -6098.004839
# Iteration 09, M-Step Ind Points end: -6098.004839
# Iteration 10, E-Step start
# Step: 0, negative lower bound: -6098.317917
# Step: 1, negative lower bound: -6098.318659
# Iteration 10, E-Step end: -6098.318659
# Iteration 10, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6133.897697
# Step: 1, negative sum of expected log likelihood: -6133.900943
# Step: 2, negative sum of expected log likelihood: -6133.900946
# Iteration 10, M-Step Model Params end: -6133.900946
# Iteration 10, M-Step Kernel Params start
# Step: 0, negative lower bound: -6102.397958
# Step: 1, negative lower bound: -6102.398510
# Iteration 10, M-Step Kernel Params end: -6102.398510
# Iteration 10, M-Step Ind Points start
# Step: 0, negative lower bound: -6106.528470
# Step: 1, negative lower bound: -6106.795617
# Step: 2, negative lower bound: -6106.820037
# Step: 3, negative lower bound: -6106.826143
# Step: 4, negative lower bound: -6106.826926
# Iteration 10, M-Step Ind Points end: -6106.826926
# Iteration 11, E-Step start
# Step: 0, negative lower bound: -6107.176777
# Step: 1, negative lower bound: -6107.177077
# Iteration 11, E-Step end: -6107.177077
# Iteration 11, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6143.018029
# Step: 1, negative sum of expected log likelihood: -6143.021215
# Step: 2, negative sum of expected log likelihood: -6143.021221
# Iteration 11, M-Step Model Params end: -6143.021221
# Iteration 11, M-Step Kernel Params start
# Step: 0, negative lower bound: -6109.808020
# Step: 1, negative lower bound: -6109.808020
# Step: 2, negative lower bound: -6109.808020
# Step: 3, negative lower bound: -6109.808020
# Step: 4, negative lower bound: -6109.808020
# Step: 5, negative lower bound: -6109.808020
# Step: 6, negative lower bound: -6109.808020
# Step: 7, negative lower bound: -6109.808020
# Step: 8, negative lower bound: -6109.808020
# Step: 9, negative lower bound: -6109.808020
# Step: 10, negative lower bound: -6109.808020
# Step: 11, negative lower bound: -6109.808020
# Step: 12, negative lower bound: -6109.808020
# Step: 13, negative lower bound: -6109.808020
# Step: 14, negative lower bound: -6109.808020
# Step: 15, negative lower bound: -6109.808020
# Step: 16, negative lower bound: -6109.808020
# Step: 17, negative lower bound: -6109.808020
# Step: 18, negative lower bound: -6109.808020
# Step: 19, negative lower bound: -6109.808020
# Iteration 11, M-Step Kernel Params end: -6109.808020
# Iteration 11, M-Step Ind Points start
# Step: 0, negative lower bound: -6112.478092
# Step: 1, negative lower bound: -6112.568968
# Step: 2, negative lower bound: -6112.629008
# Step: 3, negative lower bound: -6112.631445
# Step: 4, negative lower bound: -6112.631692
# Iteration 11, M-Step Ind Points end: -6112.631692
# Iteration 12, E-Step start
# Step: 0, negative lower bound: -6112.964640
# Step: 1, negative lower bound: -6112.965022
# Iteration 12, E-Step end: -6112.965022
# Iteration 12, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6149.096859
# Step: 1, negative sum of expected log likelihood: -6149.097486
# Iteration 12, M-Step Model Params end: -6149.097486
# Iteration 12, M-Step Kernel Params start
# Step: 0, negative lower bound: -6114.766850
# Step: 1, negative lower bound: -6114.768792
# Step: 2, negative lower bound: -6114.770743
# Step: 3, negative lower bound: -6114.776030
# Step: 4, negative lower bound: -6114.821873
# Step: 5, negative lower bound: -6115.044090
# Step: 6, negative lower bound: -6115.088848
# Step: 7, negative lower bound: -6115.091592
# Step: 8, negative lower bound: -6115.097815
# Step: 9, negative lower bound: -6115.605924
# Step: 10, negative lower bound: -6115.610684
# Step: 11, negative lower bound: -6115.610778
# Iteration 12, M-Step Kernel Params end: -6115.610778
# Iteration 12, M-Step Ind Points start
# Step: 0, negative lower bound: -6117.519514
# Step: 1, negative lower bound: -6117.571436
# Step: 2, negative lower bound: -6117.582920
# Step: 16, negative lower bound: -6126.548333
# Step: 17, negative lower bound: -6126.548333
# Step: 18, negative lower bound: -6126.548333
# Step: 19, negative lower bound: -6126.548333
# Iteration 16, M-Step Kernel Params end: -6126.548333
# Iteration 16, M-Step Ind Points start
# Step: 0, negative lower bound: -6127.242712
# Step: 1, negative lower bound: -6127.268586
# Step: 2, negative lower bound: -6127.268862
# Iteration 16, M-Step Ind Points end: -6127.268862
# Iteration 17, E-Step start
# Step: 0, negative lower bound: -6127.482842
# Step: 1, negative lower bound: -6127.483744
# Iteration 17, E-Step end: -6127.483744
# Iteration 17, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6163.560271
# Step: 1, negative sum of expected log likelihood: -6163.562359
# Step: 2, negative sum of expected log likelihood: -6163.562362
# Iteration 17, M-Step Model Params end: -6163.562362
# Iteration 17, M-Step Kernel Params start
# Step: 0, negative lower bound: -6127.985699
# Step: 1, negative lower bound: -6127.985699
# Step: 2, negative lower bound: -6127.985699
# Step: 3, negative lower bound: -6127.985699
# Step: 4, negative lower bound: -6127.985699
# Step: 5, negative lower bound: -6127.985699
# Step: 6, negative lower bound: -6127.985699
# Step: 7, negative lower bound: -6127.985699
# Step: 8, negative lower bound: -6127.985699
# Step: 9, negative lower bound: -6127.985699
# Step: 10, negative lower bound: -6127.985699
# Step: 11, negative lower bound: -6127.985699
# Step: 12, negative lower bound: -6127.985699
# Step: 13, negative lower bound: -6127.985699
# Step: 14, negative lower bound: -6127.985699
# Step: 15, negative lower bound: -6127.985699
# Step: 16, negative lower bound: -6127.985699
# Step: 17, negative lower bound: -6127.985699
# Step: 18, negative lower bound: -6127.985699
# Step: 19, negative lower bound: -6127.985699
# Iteration 17, M-Step Kernel Params end: -6127.985699
# Iteration 17, M-Step Ind Points start
# Step: 0, negative lower bound: -6128.549447
# Step: 1, negative lower bound: -6128.564809
# Step: 2, negative lower bound: -6128.565866
# Step: 3, negative lower bound: -6128.565934
# Iteration 17, M-Step Ind Points end: -6128.565934
# Iteration 18, E-Step start
# Step: 0, negative lower bound: -6128.763425
# Step: 1, negative lower bound: -6128.763521
# Iteration 18, E-Step end: -6128.763521
# Iteration 18, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6164.989135
# Step: 1, negative sum of expected log likelihood: -6164.990609
# Step: 2, negative sum of expected log likelihood: -6164.990609
# Iteration 18, M-Step Model Params end: -6164.990609
# Iteration 18, M-Step Kernel Params start
# Step: 0, negative lower bound: -6129.150192
# Step: 1, negative lower bound: -6129.150192
# Step: 2, negative lower bound: -6129.150192
# Step: 3, negative lower bound: -6129.150192
# Step: 4, negative lower bound: -6129.150192
# Step: 5, negative lower bound: -6129.150192
# Step: 6, negative lower bound: -6129.150192
# Step: 7, negative lower bound: -6129.150192
# Step: 8, negative lower bound: -6129.150192
# Step: 9, negative lower bound: -6129.150192
# Step: 10, negative lower bound: -6129.150192
# Step: 11, negative lower bound: -6129.150192
# Step: 12, negative lower bound: -6129.150192
# Step: 11, negative lower bound: -6130.898240
# Step: 12, negative lower bound: -6130.898240
# Step: 13, negative lower bound: -6130.898240
# Step: 14, negative lower bound: -6130.898240
# Step: 15, negative lower bound: -6130.898240
# Step: 16, negative lower bound: -6130.898240
# Step: 17, negative lower bound: -6130.898240
# Step: 18, negative lower bound: -6130.898240
# Step: 19, negative lower bound: -6130.898240
# Iteration 20, M-Step Kernel Params end: -6130.898240
# Iteration 20, M-Step Ind Points start
# Step: 0, negative lower bound: -6131.223674
# Step: 1, negative lower bound: -6131.228705
# Step: 2, negative lower bound: -6131.232316
# Step: 3, negative lower bound: -6131.232472
# Iteration 20, M-Step Ind Points end: -6131.232472
# Iteration 21, E-Step start
# Step: 0, negative lower bound: -6131.388276
# Step: 1, negative lower bound: -6131.388318
# Iteration 21, E-Step end: -6131.388318
# Iteration 21, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6168.008539
# Step: 1, negative sum of expected log likelihood: -6168.008763
# Iteration 21, M-Step Model Params end: -6168.008763
# Iteration 21, M-Step Kernel Params start
# Step: 0, negative lower bound: -6131.567815
# Step: 1, negative lower bound: -6131.567815
# Step: 2, negative lower bound: -6131.567815
# Step: 3, negative lower bound: -6131.567815
# Step: 4, negative lower bound: -6131.567815
# Step: 5, negative lower bound: -6131.567815
# Step: 6, negative lower bound: -6131.567815
# Step: 7, negative lower bound: -6131.567815
# Step: 8, negative lower bound: -6131.567815
# Step: 9, negative lower bound: -6131.567815
# Step: 10, negative lower bound: -6131.567815
# Step: 11, negative lower bound: -6131.567815
# Step: 12, negative lower bound: -6131.567815
# Step: 13, negative lower bound: -6131.567815
# Step: 14, negative lower bound: -6131.567815
# Step: 15, negative lower bound: -6131.567815
# Step: 16, negative lower bound: -6131.567815
# Step: 17, negative lower bound: -6131.567815
# Step: 18, negative lower bound: -6131.567815
# Step: 19, negative lower bound: -6131.567815
# Iteration 21, M-Step Kernel Params end: -6131.567815
# Iteration 21, M-Step Ind Points start
# Step: 0, negative lower bound: -6131.845728
# Step: 1, negative lower bound: -6131.852010
# Step: 2, negative lower bound: -6131.854357
# Step: 3, negative lower bound: -6131.854461
# Iteration 21, M-Step Ind Points end: -6131.854461
# Iteration 22, E-Step start
# Step: 0, negative lower bound: -6131.999879
# Step: 1, negative lower bound: -6131.999915
# Iteration 22, E-Step end: -6131.999915
# Iteration 22, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6168.722971
# Step: 1, negative sum of expected log likelihood: -6168.723213
# Iteration 22, M-Step Model Params end: -6168.723213
# Iteration 22, M-Step Kernel Params start
# Step: 0, negative lower bound: -6132.139360
# Step: 1, negative lower bound: -6132.139360
# Step: 2, negative lower bound: -6132.139360
# Step: 3, negative lower bound: -6132.139360
# Step: 4, negative lower bound: -6132.139360
# Step: 5, negative lower bound: -6132.139360
# Step: 6, negative lower bound: -6132.139360
# Step: 7, negative lower bound: -6132.139360
# Step: 8, negative lower bound: -6132.139360
# Step: 10, negative lower bound: -6133.058176
# Step: 11, negative lower bound: -6133.058176
# Step: 12, negative lower bound: -6133.058176
# Step: 13, negative lower bound: -6133.058176
# Step: 14, negative lower bound: -6133.058176
# Step: 15, negative lower bound: -6133.058176
# Step: 16, negative lower bound: -6133.058176
# Step: 17, negative lower bound: -6133.058176
# Step: 18, negative lower bound: -6133.058176
# Step: 19, negative lower bound: -6133.058176
# Iteration 24, M-Step Kernel Params end: -6133.058176
# Iteration 24, M-Step Ind Points start
# Step: 0, negative lower bound: -6133.236129
# Step: 1, negative lower bound: -6133.245047
# Step: 2, negative lower bound: -6133.251496
# Step: 3, negative lower bound: -6133.252021
# Iteration 24, M-Step Ind Points end: -6133.252021
# Iteration 25, E-Step start
# Step: 0, negative lower bound: -6133.364801
# Step: 1, negative lower bound: -6133.365019
# Iteration 25, E-Step end: -6133.365019
# Iteration 25, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6170.307338
# Step: 1, negative sum of expected log likelihood: -6170.307362
# Iteration 25, M-Step Model Params end: -6170.307362
# Iteration 25, M-Step Kernel Params start
# Step: 0, negative lower bound: -6133.431114
# Step: 1, negative lower bound: -6133.431114
# Step: 2, negative lower bound: -6133.431114
# Step: 3, negative lower bound: -6133.431114
# Step: 4, negative lower bound: -6133.431114
# Step: 5, negative lower bound: -6133.431114
# Step: 6, negative lower bound: -6133.431114
# Step: 7, negative lower bound: -6133.431114
# Step: 8, negative lower bound: -6133.431114
# Step: 9, negative lower bound: -6133.431114
# Step: 10, negative lower bound: -6133.431114
# Step: 11, negative lower bound: -6133.431114
# Step: 12, negative lower bound: -6133.431114
# Step: 13, negative lower bound: -6133.431114
# Step: 14, negative lower bound: -6133.431114
# Step: 15, negative lower bound: -6133.431114
# Step: 16, negative lower bound: -6133.431114
# Step: 17, negative lower bound: -6133.431114
# Step: 18, negative lower bound: -6133.431114
# Step: 19, negative lower bound: -6133.431114
# Iteration 25, M-Step Kernel Params end: -6133.431114
# Iteration 25, M-Step Ind Points start
# Step: 0, negative lower bound: -6133.593639
# Step: 1, negative lower bound: -6133.603048
# Step: 2, negative lower bound: -6133.604224
# Step: 3, negative lower bound: -6133.604519
# Iteration 25, M-Step Ind Points end: -6133.604519
# Iteration 26, E-Step start
# Step: 0, negative lower bound: -6133.710528
# Step: 1, negative lower bound: -6133.710560
# Iteration 26, E-Step end: -6133.710560
# Iteration 26, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6170.699707
# Step: 1, negative sum of expected log likelihood: -6170.699711
# Iteration 26, M-Step Model Params end: -6170.699711
# Iteration 26, M-Step Kernel Params start
# Step: 0, negative lower bound: -6133.762371
# Step: 1, negative lower bound: -6133.762371
# Step: 2, negative lower bound: -6133.762371
# Step: 3, negative lower bound: -6133.762371
# Step: 4, negative lower bound: -6133.762371
# Step: 5, negative lower bound: -6133.762371
# Step: 6, negative lower bound: -6133.762371
# Step: 7, negative lower bound: -6133.762371
# Step: 5, negative lower bound: -6134.779088
# Step: 6, negative lower bound: -6134.779088
# Step: 7, negative lower bound: -6134.779088
# Step: 8, negative lower bound: -6134.779088
# Step: 9, negative lower bound: -6134.779088
# Step: 10, negative lower bound: -6134.779088
# Step: 11, negative lower bound: -6134.779088
# Step: 12, negative lower bound: -6134.779088
# ...
# Step: 16, negative lower bound: -6136.085554
# Step: 17, negative lower bound: -6136.085554
# Step: 18, negative lower bound: -6136.085554
# Step: 19, negative lower bound: -6136.085554
# Iteration 39, M-Step Kernel Params end: -6136.085554
# Iteration 39, M-Step Ind Points start
# Step: 0, negative lower bound: -6136.135055
# Step: 1, negative lower bound: -6136.141070
# Step: 2, negative lower bound: -6136.142476
# Step: 3, negative lower bound: -6136.142783
# Iteration 39, M-Step Ind Points end: -6136.142783
# Iteration 40, E-Step start
# Step: 0, negative lower bound: -6136.178173
# Step: 1, negative lower bound: -6136.178194
# Iteration 40, E-Step end: -6136.178194
# Iteration 40, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.121874
# Step: 1, negative sum of expected log likelihood: -6173.121875
# Iteration 40, M-Step Model Params end: -6173.121875
# Iteration 40, M-Step Kernel Params start
# Step: 0, negative lower bound: -6136.182873
# Step: 1, negative lower bound: -6136.182873
# Step: 2, negative lower bound: -6136.182873
# Step: 3, negative lower bound: -6136.182873
# Step: 4, negative lower bound: -6136.182873
# Step: 5, negative lower bound: -6136.182873
# Step: 6, negative lower bound: -6136.182873
# Step: 7, negative lower bound: -6136.182873
# Step: 8, negative lower bound: -6136.182873
# Step: 9, negative lower bound: -6136.182873
# Step: 10, negative lower bound: -6136.182873
# Step: 11, negative lower bound: -6136.182873
# Step: 12, negative lower bound: -6136.182873
# Step: 13, negative lower bound: -6136.182873
# Step: 14, negative lower bound: -6136.182873
# Step: 15, negative lower bound: -6136.182873
# Step: 16, negative lower bound: -6136.182873
# Step: 17, negative lower bound: -6136.182873
# Step: 18, negative lower bound: -6136.182873
# Step: 19, negative lower bound: -6136.182873
# Iteration 40, M-Step Kernel Params end: -6136.182873
# Iteration 40, M-Step Ind Points start
# Step: 0, negative lower bound: -6136.224862
# Step: 1, negative lower bound: -6136.233771
# Step: 2, negative lower bound: -6136.235037
# Step: 3, negative lower bound: -6136.236135
# Step: 4, negative lower bound: -6136.236432
# Iteration 40, M-Step Ind Points end: -6136.236432
# Iteration 41, E-Step start
# Step: 0, negative lower bound: -6136.269191
# Step: 1, negative lower bound: -6136.269197
# Iteration 41, E-Step end: -6136.269197
# Iteration 41, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.191075
# Step: 1, negative sum of expected log likelihood: -6173.191090
# Iteration 41, M-Step Model Params end: -6173.191090
# Iteration 41, M-Step Kernel Params start
# Step: 0, negative lower bound: -6136.273568
# Step: 1, negative lower bound: -6136.273568
# Step: 2, negative lower bound: -6136.273568
# Step: 3, negative lower bound: -6136.273568
# Step: 4, negative lower bound: -6136.273568
# Step: 5, negative lower bound: -6136.273568
# Step: 6, negative lower bound: -6136.273568
# Step: 7, negative lower bound: -6136.273568
# Step: 8, negative lower bound: -6136.273568
# Step: 9, negative lower bound: -6136.273568
# Step: 10, negative lower bound: -6136.273568
# Step: 11, negative lower bound: -6136.273568
# Step: 12, negative lower bound: -6136.273568
# Step: 13, negative lower bound: -6136.273568
# Step: 14, negative lower bound: -6136.273568
# Step: 15, negative lower bound: -6136.273568
# Step: 16, negative lower bound: -6136.273568
# Step: 17, negative lower bound: -6136.273568
# Step: 18, negative lower bound: -6136.273568
# Step: 19, negative lower bound: -6136.273568
# Iteration 41, M-Step Kernel Params end: -6136.273568
# Iteration 41, M-Step Ind Points start
# Step: 0, negative lower bound: -6136.317847
# Step: 1, negative lower bound: -6136.321673
# Step: 2, negative lower bound: -6136.322890
# Step: 3, negative lower bound: -6136.323823
# Iteration 41, M-Step Ind Points end: -6136.323823
# Iteration 42, E-Step start
# Step: 0, negative lower bound: -6136.353964
# Step: 1, negative lower bound: -6136.353968
# Iteration 42, E-Step end: -6136.353968
# Iteration 42, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.253970
# Step: 1, negative sum of expected log likelihood: -6173.253970
# Iteration 42, M-Step Model Params end: -6173.253970
# Iteration 42, M-Step Kernel Params start
# Step: 0, negative lower bound: -6136.358172
# Step: 1, negative lower bound: -6136.358172
# Step: 2, negative lower bound: -6136.358172
# Step: 3, negative lower bound: -6136.358172
# Step: 4, negative lower bound: -6136.358172
# Step: 5, negative lower bound: -6136.358172
# Step: 6, negative lower bound: -6136.358172
# Step: 7, negative lower bound: -6136.358172
# Step: 8, negative lower bound: -6136.358172
# Step: 9, negative lower bound: -6136.358172
# Step: 10, negative lower bound: -6136.358172
# Step: 11, negative lower bound: -6136.358172
# Step: 12, negative lower bound: -6136.358172
# Step: 13, negative lower bound: -6136.358172
# Step: 14, negative lower bound: -6136.358172
# Step: 15, negative lower bound: -6136.358172
# Step: 16, negative lower bound: -6136.358172
# Step: 17, negative lower bound: -6136.358172
# Step: 18, negative lower bound: -6136.358172
# Step: 19, negative lower bound: -6136.358172
# Iteration 42, M-Step Kernel Params end: -6136.358172
# Iteration 42, M-Step Ind Points start
# Step: 0, negative lower bound: -6136.395950
# Step: 1, negative lower bound: -6136.403656
# Step: 2, negative lower bound: -6136.404757
# Step: 3, negative lower bound: -6136.405468
# Iteration 42, M-Step Ind Points end: -6136.405468
# Iteration 43, E-Step start
# Step: 0, negative lower bound: -6136.433991
# Step: 1, negative lower bound: -6136.434016
# Iteration 43, E-Step end: -6136.434016
# Iteration 43, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.311570
# Step: 1, negative sum of expected log likelihood: -6173.311574
# Iteration 43, M-Step Model Params end: -6173.311574
# Iteration 43, M-Step Kernel Params start
# Step: 0, negative lower bound: -6138.018438
# Step: 1, negative lower bound: -6138.906090
# Step: 2, negative lower bound: -6139.368698
# Step: 3, negative lower bound: -6139.586789
# Step: 4, negative lower bound: -6139.587553
# Iteration 43, M-Step Kernel Params end: -6139.587553
# Iteration 43, M-Step Ind Points start
# Step: 0, negative lower bound: -6139.820175
# Step: 1, negative lower bound: -6139.867911
# Step: 2, negative lower bound: -6139.873145
# Step: 3, negative lower bound: -6139.874119
# Iteration 43, M-Step Ind Points end: -6139.874119
# Iteration 44, E-Step start
# Step: 0, negative lower bound: -6139.926433
# Step: 1, negative lower bound: -6139.926810
# Iteration 44, E-Step end: -6139.926810
# Iteration 44, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6172.994449
# Step: 1, negative sum of expected log likelihood: -6172.994693
# Iteration 44, M-Step Model Params end: -6172.994693
# Iteration 44, M-Step Kernel Params start
# Step: 0, negative lower bound: -6140.116690
# Step: 1, negative lower bound: -6140.116690
# Step: 2, negative lower bound: -6140.116690
# Step: 3, negative lower bound: -6140.116690
# Step: 4, negative lower bound: -6140.116690
# Step: 5, negative lower bound: -6140.116690
# Step: 6, negative lower bound: -6140.116690
# Step: 7, negative lower bound: -6140.116690
# Step: 8, negative lower bound: -6140.116690
# Step: 9, negative lower bound: -6140.116690
# Step: 10, negative lower bound: -6140.116690
# Step: 11, negative lower bound: -6140.116690
# Step: 12, negative lower bound: -6140.116690
# Step: 13, negative lower bound: -6140.116690
# Step: 14, negative lower bound: -6140.116690
# Step: 15, negative lower bound: -6140.116690
# Step: 16, negative lower bound: -6140.116690
# Step: 17, negative lower bound: -6140.116690
# Step: 18, negative lower bound: -6140.116690
# Step: 19, negative lower bound: -6140.116690
# Iteration 44, M-Step Kernel Params end: -6140.116690
# Iteration 44, M-Step Ind Points start
# Step: 0, negative lower bound: -6140.170224
# Step: 1, negative lower bound: -6140.207909
# Step: 2, negative lower bound: -6140.212835
# Step: 3, negative lower bound: -6140.214280
# Step: 4, negative lower bound: -6140.214540
# Iteration 44, M-Step Ind Points end: -6140.214540
# Iteration 45, E-Step start
# Step: 0, negative lower bound: -6140.252269
# Step: 1, negative lower bound: -6140.252319
# Iteration 45, E-Step end: -6140.252319
# Iteration 45, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.385660
# Step: 1, negative sum of expected log likelihood: -6173.385934
# Iteration 45, M-Step Model Params end: -6173.385934
# Iteration 45, M-Step Kernel Params start
# Step: 0, negative lower bound: -6140.405572
# Step: 1, negative lower bound: -6140.405572
# Step: 2, negative lower bound: -6140.405572
# Step: 3, negative lower bound: -6140.405572
# Step: 4, negative lower bound: -6140.405572
# Step: 5, negative lower bound: -6140.405572
# Step: 6, negative lower bound: -6140.405572
# Step: 7, negative lower bound: -6140.405572
# Step: 8, negative lower bound: -6140.405572
# Step: 9, negative lower bound: -6140.405572
# Step: 10, negative lower bound: -6140.405572
# Step: 11, negative lower bound: -6140.405572
# Step: 12, negative lower bound: -6140.405572
# Step: 13, negative lower bound: -6140.405572
# Step: 14, negative lower bound: -6140.405572
# Step: 15, negative lower bound: -6140.405572
# Step: 16, negative lower bound: -6140.405572
# Step: 17, negative lower bound: -6140.405572
# Step: 18, negative lower bound: -6140.405572
# Step: 19, negative lower bound: -6140.405572
# Iteration 45, M-Step Kernel Params end: -6140.405572
# Iteration 45, M-Step Ind Points start
# Step: 0, negative lower bound: -6140.454605
# Step: 1, negative lower bound: -6140.468073
# Step: 2, negative lower bound: -6140.469381
# Step: 3, negative lower bound: -6140.470078
# Iteration 45, M-Step Ind Points end: -6140.470078
# Iteration 46, E-Step start
# Step: 0, negative lower bound: -6140.511225
# Step: 1, negative lower bound: -6140.511262
# Iteration 46, E-Step end: -6140.511262
# Iteration 46, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6173.719819
# Step: 1, negative sum of expected log likelihood: -6173.720064
# Iteration 46, M-Step Model Params end: -6173.720064
# Iteration 46, M-Step Kernel Params start
# Step: 0, negative lower bound: -6140.638230
# Step: 1, negative lower bound: -6140.638230
# Step: 2, negative lower bound: -6140.638230
# Step: 3, negative lower bound: -6140.638230
# Step: 4, negative lower bound: -6140.638230
# Step: 5, negative lower bound: -6140.638230
# Step: 6, negative lower bound: -6140.638230
# Step: 7, negative lower bound: -6140.638230
# Step: 8, negative lower bound: -6140.638230
# Step: 9, negative lower bound: -6140.638230
# Step: 10, negative lower bound: -6140.638230
# Step: 11, negative lower bound: -6140.638230
# Step: 12, negative lower bound: -6140.638230
# Step: 13, negative lower bound: -6140.638230
# Step: 14, negative lower bound: -6140.638230
# Step: 15, negative lower bound: -6140.638230
# Step: 16, negative lower bound: -6140.638230
# Step: 17, negative lower bound: -6140.638230
# Step: 18, negative lower bound: -6140.638230
# Step: 19, negative lower bound: -6140.638230
# Iteration 46, M-Step Kernel Params end: -6140.638230
# Iteration 46, M-Step Ind Points start
# Step: 0, negative lower bound: -6140.677499
# Step: 1, negative lower bound: -6140.680427
# Step: 2, negative lower bound: -6140.681624
# Step: 3, negative lower bound: -6140.682210
# Iteration 46, M-Step Ind Points end: -6140.682210
# Iteration 47, E-Step start
# Step: 0, negative lower bound: -6140.725022
# Step: 1, negative lower bound: -6140.725604
# Iteration 47, E-Step end: -6140.725604
# Iteration 47, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6174.015563
# Step: 1, negative sum of expected log likelihood: -6174.015792
# Iteration 47, M-Step Model Params end: -6174.015792
# Iteration 47, M-Step Kernel Params start
# Step: 0, negative lower bound: -6140.830550
# Step: 1, negative lower bound: -6140.830550
# Step: 2, negative lower bound: -6140.830550
# Step: 3, negative lower bound: -6140.830550
# Step: 4, negative lower bound: -6140.830550
# Step: 5, negative lower bound: -6140.830550
# Step: 6, negative lower bound: -6140.830550
# Step: 7, negative lower bound: -6140.830550
# Step: 8, negative lower bound: -6140.830550
# Step: 9, negative lower bound: -6140.830550
# Step: 10, negative lower bound: -6140.830550
# Step: 11, negative lower bound: -6140.830550
# Step: 12, negative lower bound: -6140.830550
# Step: 13, negative lower bound: -6140.830550
# Step: 14, negative lower bound: -6140.830550
# Step: 15, negative lower bound: -6140.830550
# Step: 16, negative lower bound: -6140.830550
# Step: 17, negative lower bound: -6140.830550
# Step: 18, negative lower bound: -6140.830550
# Step: 19, negative lower bound: -6140.830550
# Iteration 47, M-Step Kernel Params end: -6140.830550
# Iteration 47, M-Step Ind Points start
# Step: 0, negative lower bound: -6140.856404
# Step: 1, negative lower bound: -6140.860520
# Step: 2, negative lower bound: -6140.861054
# Iteration 47, M-Step Ind Points end: -6140.861054
# Iteration 48, E-Step start
# Step: 0, negative lower bound: -6140.904946
# Step: 1, negative lower bound: -6140.904996
# Iteration 48, E-Step end: -6140.904996
# Iteration 48, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6174.282816
# Step: 1, negative sum of expected log likelihood: -6174.282979
# Iteration 48, M-Step Model Params end: -6174.282979
# Iteration 48, M-Step Kernel Params start
# Step: 0, negative lower bound: -6140.993413
# Step: 1, negative lower bound: -6140.993413
# Step: 2, negative lower bound: -6140.993413
# Step: 3, negative lower bound: -6140.993413
# Step: 4, negative lower bound: -6140.993413
# Step: 5, negative lower bound: -6140.993413
# Step: 6, negative lower bound: -6140.993413
# Step: 7, negative lower bound: -6140.993413
# Step: 8, negative lower bound: -6140.993413
# Step: 9, negative lower bound: -6140.993413
# Step: 10, negative lower bound: -6140.993413
# Step: 11, negative lower bound: -6140.993413
# Step: 12, negative lower bound: -6140.993413
# Step: 13, negative lower bound: -6140.993413
# Step: 14, negative lower bound: -6140.993413
# Step: 15, negative lower bound: -6140.993413
# Step: 16, negative lower bound: -6140.993413
# Step: 17, negative lower bound: -6140.993413
# Step: 18, negative lower bound: -6140.993413
# Step: 19, negative lower bound: -6140.993413
# Iteration 48, M-Step Kernel Params end: -6140.993413
# Iteration 48, M-Step Ind Points start
# Step: 0, negative lower bound: -6141.013231
# Step: 1, negative lower bound: -6141.014970
# Step: 2, negative lower bound: -6141.015255
# Iteration 48, M-Step Ind Points end: -6141.015255
# Iteration 49, E-Step start
# Step: 0, negative lower bound: -6141.057685
# Step: 1, negative lower bound: -6141.057710
# Iteration 49, E-Step end: -6141.057710
# Iteration 49, M-Step Model Params start
# Step: 0, negative sum of expected log likelihood: -6174.524600
# Step: 1, negative sum of expected log likelihood: -6174.524729
# Iteration 49, M-Step Model Params end: -6174.524729
# Iteration 49, M-Step Kernel Params start
# Step: 0, negative lower bound: -6141.131785
# Step: 1, negative lower bound: -6141.131785
# Step: 2, negative lower bound: -6141.131785
# Step: 3, negative lower bound: -6141.131785
# Step: 4, negative lower bound: -6141.131785
# Step: 5, negative lower bound: -6141.131785
# Step: 6, negative lower bound: -6141.131785
# Step: 7, negative lower bound: -6141.131785
# Step: 8, negative lower bound: -6141.131785
# Step: 9, negative lower bound: -6141.131785
# Step: 10, negative lower bound: -6141.131785
# Step: 11, negative lower bound: -6141.131785
# Step: 12, negative lower bound: -6141.131785
# Step: 13, negative lower bound: -6141.131785
# Step: 14, negative lower bound: -6141.131785
# Step: 15, negative lower bound: -6141.131785
# Step: 16, negative lower bound: -6141.131785
# Step: 17, negative lower bound: -6141.131785
# Step: 18, negative lower bound: -6141.131785
# Step: 19, negative lower bound: -6141.131785
# Iteration 49, M-Step Kernel Params end: -6141.131785
# Iteration 49, M-Step Ind Points start
# Step: 0, negative lower bound: -6141.145890
# Step: 1, negative lower bound: -6141.147564
# Step: 2, negative lower bound: -6141.147678
# Iteration 49, M-Step Ind Points end: -6141.147678

# %% [markdown]
# # Plot lower bound history

# %%
# %matplotlib inline
plt.figure()
plot.svGPFA.plotUtils.plotLowerBoundHist(lowerBoundHist=lowerBoundHist)

# %% [markdown]
# # Predict true and estimated latents

# %%
    testMuK, testVarK = model.predictLatents(newTimes=testTimes)
    indPointsLocs = model.getIndPointsLocs()
    plot.svGPFA.plotUtils.plotTrueAndEstimatedLatents(timesEstimatedValues=testTimes, muK=testMuK, varK=testVarK, indPointsLocs=indPointsLocs, timesTrueValues=timesTrueValues, trueLatents=trueLatents, trueLatentsMeans=trueLatentsMeans, trueLatentsSTDs=trueLatentsSTDs, trialToPlot=trialToPlot)

# %% [markdown]
# # Plot true and estimated kernels parameters

# %%
    kernelsParams = model.getKernelsParams()
    plot.svGPFA.plotUtils.plotTrueAndEstimatedKernelsParams(trueKernels=kernels, estimatedKernelsParams=kernelsParams)

# %% [markdown]
# # Plot true and estimated latents means

# %%
    tLatentsMeansFuncs = utils.svGPFA.configUtils.getLatentsMeansFuncs(nLatents=nLatents, nTrials=nTrials, config=simInitConfig)
    trialsTimes = utils.svGPFA.miscUtils.getTrialsTimes(trialsLengths=trialsLengths, dt=dtSimulate)
    tLatentsMeans = utils.svGPFA.miscUtils.getLatentsMeanFuncsSamples(latentsMeansFuncs=tLatentsMeansFuncs, trialsTimes=trialsTimes, dtype=C.dtype)
    with torch.no_grad(): latentsMeans, _ = model.predictLatents(newTimes=trialsTimes[0])

    plot.svGPFA.plotUtils.plotTrueAndEstimatedLatentsMeans(trueLatentsMeans=tLatentsMeans, estimatedLatentsMeans=latentsMeans, trialsTimes=trialsTimes)

# %% [markdown]
# # Plot true and estimated linear embedding parameters

# %%
    with torch.no_grad(): estimatedC, estimatedD = model.getSVEmbeddingParams()
    plt.figure()
    plot.svGPFA.plotUtils.plotTrueAndEstimatedEmbeddingParams(trueC=C, trueD=d, estimatedC=estimatedC, estimatedD=estimatedD)

# %% [markdown]
# # Plot true and estimated CIF

# %%
    title = "Trial {:d}, Neuron {:d}".format(trialToPlot, neuronToPlot)                                                                       
    # CIF
    T = torch.tensor(trialsLengths).max().item()
    oneTrialCIFTimes = torch.arange(0, T, dtCIF)
    cifTimes = torch.unsqueeze(torch.ger(torch.ones(nTrials), oneTrialCIFTimes), dim=2)
    with torch.no_grad(): cifValues = model.computeMeanCIFs(times=cifTimes)
    plt.figure()
    plot.svGPFA.plotUtils.plotSimulatedAndEstimatedCIFs(times=cifTimes[trialToPlot, :, 0], simCIFValues=simCIFsValues[trialToPlot][neuronToPlot], estCIFValues=cifValues[trialToPlot][neuronToPlot], title=title)

# %% [markdown]
# # KS time-rescaling GOF test -- numerical correction

# %%
    gamma = 10 # number of resamples
    spikesTimesKS = spikesTimes[trialToPlot][neuronToPlot]
    cifTimesKS = cifTimes[trialToPlot,:,0]
    cifValuesKS = cifValues[trialToPlot][neuronToPlot]

    title = "Trial {:d}, Neuron {:d} ({:d} spikes)".format(trialToPlot, neuronToPlot, len(spikesTimesKS))

    diffECDFsX, diffECDFsY, estECDFx, estECDFy, simECDFx, simECDFy, cb = stats.pointProcess.tests.KSTestTimeRescalingNumericalCorrection(spikesTimes=spikesTimesKS, cifTimes=cifTimesKS, cifValues=cifValuesKS, gamma=gamma)
    plt.figure()
    plot.svGPFA.plotUtils.plotResKSTestTimeRescalingNumericalCorrection(diffECDFsX=diffECDFsX, diffECDFsY=diffECDFsY, estECDFx=estECDFx, estECDFy=estECDFy, simECDFx=simECDFx, simECDFy=simECDFy, cb=cb, title=title)
# Out:
# Processing given ISIs
# Processing iter 0/9
# Processing iter 1/9
# Processing iter 2/9
# Processing iter 3/9
# Processing iter 4/9
# Processing iter 5/9
# Processing iter 6/9
# Processing iter 7/9
# Processing iter 8/9
# Processing iter 9/9

# %% [markdown]
# # KS time-rescaling GOF test -- analytical correction

# %%
    t0 = math.floor(cifTimesKS.min())
    tf = math.ceil(cifTimesKS.max())
    dt = (cifTimesKS[1]-cifTimesKS[0]).item()
    utSRISIs, uCDF, cb, utRISIs = stats.pointProcess.tests.KSTestTimeRescalingAnalyticalCorrectionUnbinned(spikesTimes=spikesTimesKS, cifValues=cifValuesKS, t0=t0, tf=tf, dt=dt)
    sUTRISIs, _ = torch.sort(utSRISIs)

    plt.figure()
    plot.svGPFA.plotUtils.plotResKSTestTimeRescalingAnalyticalCorrection(sUTRISIs=sUTRISIs, uCDF=uCDF, cb=cb, title=title)

# %% [markdown]
# ## Plot rescaled ISIs 1-lag scatter plot

# %%
    plt.figure()
    plot.svGPFA.plotUtils.plotScatter1Lag(x=utRISIs, title=title)

# %% [markdown]
# ## Plot rescaled ISIs autorocorrelogram

# %%
    acfRes, confint = statsmodels.tsa.stattools.acf(x=utRISIs, unbiased=True, alpha=0.05)
    plt.figure()
    plot.svGPFA.plotUtils.plotACF(acf=acfRes, Fs=1/dt, confint=confint, title=title)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # ROC predictive analysis

# %%
    pk = cifValuesKS*dtCIF
    bins = pd.interval_range(start=0, end=T, periods=len(pk))
    cutRes, _ = pd.cut(spikesTimesKS, bins=bins, retbins=True)
    Y = torch.from_numpy(cutRes.value_counts().values)
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y, pk, pos_label=1)
    roc_auc = sklearn.metrics.auc(fpr, tpr)
    plt.figure()
    plot.svGPFA.plotUtils.plotResROCAnalysis(fpr=fpr, tpr=tpr, auc=roc_auc, title=title)
